# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Azure OpenAI Configuration (uncomment if using Azure)
# azure_openai_api_key = "your-azure-openai-key"
# azure_openai_endpoint = "https://your-instance.openai.azure.com/"
# azure_openai_deployment = "gpt-4o-mini"  # Your deployment name

# Example of creating Azure OpenAI LLM
# from langchain_openai import AzureChatOpenAI
# llm_azure = AzureChatOpenAI(
#     api_key=azure_openai_api_key,
#     azure_endpoint=azure_openai_endpoint,
#     deployment_name=azure_openai_deployment,
#     api_version="2024-02-01"
# )

print("🔧 Azure OpenAI configuration example provided (commented out)")
print("Uncomment and modify with your Azure OpenAI details if needed")
# Out:
# 🔧 Azure OpenAI configuration example provided (commented out)
# Uncomment and modify with your Azure OpenAI details if needed

# %%
from langchain_openai import ChatOpenAI

# Create an LLM instance - traditional way
llm_traditional = ChatOpenAI(
    model="gpt-5-nano",
    temperature=0.7,
    max_tokens=100
)

# %%
from langchain.chat_models import init_chat_model

# Create LLM using the new unified initialization method
llm_unified = init_chat_model(
    model="gpt-4.1-mini",
    model_provider="openai",
    temperature=0.7,
    max_tokens=100
)

# %%
from langchain.messages import HumanMessage, SystemMessage, AIMessage

# Create different types of messages
system_msg = SystemMessage(content="You are a helpful AI assistant that explains concepts clearly.")
human_msg = HumanMessage(content="Explain what LangChain 1.0 is in simple terms.")

messages = [system_msg, human_msg]

messages
# Out:
# [SystemMessage(content='You are a helpful AI assistant that explains concepts clearly.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Explain what LangChain 1.0 is in simple terms.', additional_kwargs={}, response_metadata={})]

# %%
# Send messages to the LLM
response = llm_unified.invoke(messages)

print(" LLM Response:")
print(f"Type: {type(response).__name__}")
print(f"Content: {response.content}")
print(f"Additional info: {response.response_metadata}")
# Out:
#  LLM Response:
# Type: AIMessage
# Content: LangChain 1.0 is a software tool that helps developers build applications using large language models (like ChatGPT) more easily. It provides ready-made building blocks and tools to connect these language models with different data sources, APIs, and other services, making it simpler to create smart apps that can understand and generate human-like text. Think of it as a toolkit that helps programmers create advanced AI-powered programs without starting from scratch.
# ...

# %%
from langchain.messages import HumanMessage, AIMessage, SystemMessage

conversation = [
    {"role": "system", "content": "You are a helpful assistant that translates English to French."},
    {"role": "user", "content": "Translate: I love programming."},
    {"role": "assistant", "content": "J'adore la programmation."},
    {"role": "user", "content": "Translate: I love building applications."}
]

response = llm_unified.invoke(conversation)
print(response)
# Out:
# content="J'adore créer des applications." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 48, 'total_tokens': 54, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_baa8597c3d', 'id': 'chatcmpl-EGO5UgCmlisTObxMpNDtCJPnhR7yk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a033be-f786-76d3-9ee4-536ad7961de8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 48, 'output_tokens': 6, 'total_tokens': 54, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# Stream the response for real-time output
print("🔄 Streaming response:")
print("-" * 50)

stream = llm_unified.stream([
    SystemMessage(content="You are a concise technical writer."),
    HumanMessage(content="Write a brief summary of what makes LangChain 1.0 special.")
])

for chunk in stream:
    print(chunk.content, end="", flush=True)

print("\n" + "-" * 50)
print("✅ Streaming complete!")
# Out:
# 🔄 Streaming response:
# --------------------------------------------------
# LangChain 1.0 is notable for its robust framework that simplifies building applications with large language models (LLMs). It offers modular components for prompt management, chaining, memory, and integrations with various data sources, enabling developers to create complex, context-aware AI workflows efficiently. The release emphasizes stability, extensibility, and improved developer experience, making it a foundational tool for LLM-powered applications.
# --------------------------------------------------
# ✅ Streaming complete!

# %%
# Prepare multiple inputs for batch processing
batch_inputs = [
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
]

# Process in batch
batch_results = llm_unified.batch(batch_inputs, config={
        'max_concurrency': 5
    })

print("📦 Batch Processing Results:")
print("=" * 60)
for i, result in enumerate(batch_results, 1):
    print(f"\n{i}. {result.content}...")
    print("-" * 40)
# Out:
# 📦 Batch Processing Results:
# ...
#
# 1. Parrots have colorful feathers primarily for several biological and ecological reasons:
#
# 1. **Communication and Social Interaction:** Brightly colored feathers help parrots recognize each other, establish territories, and attract mates. Vivid colors can signal health and vitality, making individuals more attractive during courtship.
#
# 2. **Species and Individual Identification:** The unique color patterns help parrots distinguish members of their own species and even individual birds within a flock, which is important for social cohesion.
#
# 3. **Camouflage:** Although it...
# ----------------------------------------
#
# 2. Airplanes fly by generating lift, which is a force that opposes gravity and allows the plane to rise into the air. Here’s a basic explanation of how this works:
#
# ...

# %%
from langchain_core.output_parsers import StrOutputParser, JsonOutputParser

# Create a JSON parser
parser = JsonOutputParser()

# Get a JSON-style response from the model
response = llm_unified.invoke([
    HumanMessage(content="""Tell me about elon musk, history, education, 
                 work experience, skills and achievements. Give the response in json format.""")
])

parsed_output = parser.invoke(response)

print("📝 Raw Output:" , response.content)
print(f"Raw response type: {type(response)}")
print(f"Parsed output type: {type(parsed_output)}")
print(f"Parsed content: {parsed_output}")
# Out:
# 📝 Raw Output: ```json
# {
#   "name": "Elon Musk",
#   "birthDate": "1971-06-28",
#   "birthPlace": "Pretoria, South Africa",
#   "history": {
#     "earlyLife": "Elon Musk was born and raised in Pretoria, South Africa. He showed an early interest in computing and technology, teaching himself programming at a young age.",
#     "familyBackground": "His mother, Maye Musk, is a model and dietitian,
# Raw response type: <class 'langchain_core.messages.ai.AIMessage'>
# Parsed output type: <class 'dict'>
# Parsed content: {'name': 'Elon Musk', 'birthDate': '1971-06-28', 'birthPlace': 'Pretoria, South Africa', 'history': {'earlyLife': 'Elon Musk was born and raised in Pretoria, South Africa. He showed an early interest in computing and technology, teaching himself programming at a young age.', 'familyBackground': 'His mother, Maye Musk, is a model and dietitian,'}}

# %%
# Create a simple chain: LLM + JSON Parser
simple_chain = llm_unified | JsonOutputParser()

# Test the chain
result = simple_chain.invoke([
    HumanMessage(content="""Tell me about elon musk, history, education, 
                 work experience, skills and achievements. Give the response in json format.""")
])

print(f"Chain result type: {type(result)}")
print(f"Chain result: {result}")
# Out:
# Chain result type: <class 'dict'>
# Chain result: {'name': 'Elon Musk', 'history': {'birth': {'date': '1971-06-28', 'place': 'Pretoria, South Africa'}, 'early_life': 'Elon Musk showed an early interest in computing and entrepreneurship. He taught himself programming and created a video game at the age of 12.'}, 'education': {'high_school': 'Pretoria Boys High'}}

# %%
# Create a simple chain: LLM + JSON Parser
simple_chain = llm_unified | JsonOutputParser()

# Test the chain
result = simple_chain.invoke([
    HumanMessage(content="""Tell me about actor vijay, history, education, 
                 work experience, skills and achievements. Give the response in json format.""")
])

print(f"Chain result type: {type(result)}")
print(f"Chain result: {result}")
# Out:
# Chain result type: <class 'dict'>
# Chain result: {'name': 'Vijay', 'full_name': 'Joseph Vijay Chandrasekhar', 'date_of_birth': '1974-06-22', 'place_of_birth': 'Chennai, Tamil Nadu, India', 'occupation': 'Actor, Playback Singer', 'industry': 'Tamil Cinema', 'history': {'early_life': 'Vijay was born into a film family; his father, S.'}}

# %%
from langchain_core.prompts import ChatPromptTemplate

# Create a prompt template
prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are an expert in {subject}. Provide clear, concise explanations."),
    ("human", "Explain {topic} in simple terms.")
])

# Format the prompt
formatted_prompt = prompt_template.invoke({
    "subject": "software development", 
    "topic": "the differences between LangChain 0.x and 1.0"
})

print("📋 Formatted Prompt:")
for message in formatted_prompt.messages:
    print(f"{message.__class__.__name__}: {message.content}")
# Out:
# 📋 Formatted Prompt:
# SystemMessage: You are an expert in software development. Provide clear, concise explanations.
# HumanMessage: Explain the differences between LangChain 0.x and 1.0 in simple terms.

# %%
# Create a complete chain
complete_chain = prompt_template | llm_unified | StrOutputParser()

# Use the chain
explanation = complete_chain.invoke({
    "subject": "AI frameworks",
    "topic": "LangChain 1.0's unified interface design"
})

print("Complete Chain Result:")
print(explanation)
# Out:
# Complete Chain Result:
# LangChain 1.0’s unified interface design means it provides a single, consistent way to work with different components involved in building applications with language models. Instead of dealing with many separate tools each having their own unique methods and formats, LangChain offers a common set of interfaces and patterns. This makes it easier to connect things like language models, prompts, chains of calls, memory, and data sources—all work together smoothly without you needing to learn different systems for each part. In short, it simplifies

# %%
from typing import List
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field


# Define data models using Pydantic
class Person(BaseModel):
    """Information about a person."""
    name: str = Field(description="The name of the person")
    height_in_meters: float = Field(description="The height of the person expressed in meters.")

class People(BaseModel):
    """Identifying information about all people in a text."""
    people: List[Person]

# Set up a Pydantic parser
pydantic_parser = PydanticOutputParser(pydantic_object=People)

print("📋 Pydantic Parser Format Instructions:")
print(pydantic_parser.get_format_instructions())
# Out:
# 📋 Pydantic Parser Format Instructions:
# The output should be formatted as a JSON instance that conforms to the JSON schema below.
#
# As an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}
# the object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.
#
# Here is the output schema:
# ```
# ...

# %%
# Create prompt with format instructions
structured_prompt = ChatPromptTemplate.from_messages([
    ("system", "Answer the user query. Wrap the output in `json` tags\n{format_instructions}"),
    ("human", "{query}")
]).partial(format_instructions=pydantic_parser.get_format_instructions())

# Create chain with Pydantic parser
structured_chain = structured_prompt | llm_unified

# Test the structured output
query = "Siva is 44 years old and 1.7 meters tall. Rishik is 15 years old and 1.8 meters tall."
result = structured_chain.invoke({"query": query})

print("🔗 Structured Chain Result:")
print(f"Type: {type(result).__name__}")
print(f"Content: {result.content}")


parsed_people = pydantic_parser.invoke(result)
print(f"\n✅ Parsed People: {parsed_people}")
print(f"People type: {type(parsed_people)}")
print(f"First person: {parsed_people.people[0].name} - {parsed_people.people[0].height_in_meters}m")
# Out:
# 🔗 Structured Chain Result:
# Type: AIMessage
# Content: ```json
# {
#   "people": [
#     {
#       "name": "Siva",
#       "height_in_meters": 1.7
#     },
#     {
#       "name": "Rishik",
#       "height_in_meters": 1.8
#     }
#   ]
# }
# ```
#
# ✅ Parsed People: people=[Person(name='Siva', height_in_meters=1.7), Person(name='Rishik', height_in_meters=1.8)]
# People type: <class '__main__.People'>
# First person: Siva - 1.7m
