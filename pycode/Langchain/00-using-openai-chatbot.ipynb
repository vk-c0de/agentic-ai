# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
client = OpenAI()

response = client.chat.completions.create(
  model="gpt-4.1-mini",
  messages=[
    {
      "role": "system",
      "content": "Give your responses in a funny way . Limit your responses to atmost 3 sentences"
    },
    {
      "role": "user",
     # "content": "Who is elon musk?"
       "content": "tellme about thirukural with 2 examples in tamil"
    }
  ],
)
response
# Out:
# ChatCompletion(id='chatcmpl-EGiByFpavLvxsomZRHMXUQ3JaiZzW', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Ah, the Thirukkural – basically the ancient Tamil version of “How to live your best life without drama”! It’s full of 1330 tiny wisdom bombs called couplets. Example time: \n\n1. "அகர முதல எழுத்தெல்லாம் ஆதி பகவன் முதற்றே உலகு" – The letter அ (A) is the beginning of all letters, just like God is the beginning of the world. \n2. "புகழ் கொட்டிக் கற்றார்க்கு ஊக்கமு தரணார்" – Fame gives motivation to those who have learned, kind of like how applause fuels a stand-up comedian!', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1787651830, model='gpt-4.1-mini-2025-04-14', object='chat.completion', metadata=None, moderation=None, service_tier='default', system_fingerprint='fp_ad0deab038', usage=CompletionUsage(completion_tokens=131, prompt_tokens=41, total_tokens=172, complet
# ...

# %%
response.choices[0].message.content
# Out:
# 'Ah, the Thirukkural – basically the ancient Tamil version of “How to live your best life without drama”! It’s full of 1330 tiny wisdom bombs called couplets. Example time: \n\n1. "அகர முதல எழுத்தெல்லாம் ஆதி பகவன் முதற்றே உலகு" – The letter அ (A) is the beginning of all letters, just like God is the beginning of the world. \n2. "புகழ் கொட்டிக் கற்றார்க்கு ஊக்கமு தரணார்" – Fame gives motivation to those who have learned, kind of like how applause fuels a stand-up comedian!'

# %%
def get_completion_from_messages(messages, model="gpt-4.1-mini", temperature=0):
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
    # print(str(response.choices[0].message))
    return response.choices[0].message.content

# %%
messages =[]

messages.append({'role':'user', 'content': "My Name is vijay"})

get_completion_from_messages(messages)

messages.append({'role':'user', 'content': "What is my name"})

get_completion_from_messages(messages)
# Out:
# 'Your name is Vijay.'

# %%
messages=[
    {
      "role": "system",
      "content": "You are a funny ai . Give funny response"
    },
    {
      "role": "user",
      "content": "What is 2+5"
    }
  ]

get_completion_from_messages(messages=messages)
# Out:
# '2 + 5? Easy! It’s 7... unless you’re counting pizza slices, then it’s definitely “more please!” 🍕😄'

# %%
import gradio as gr

def predict(message,history):

    print("Message:", message)
    print("History:", history)

    messages = []

    for history_item in history:
        messages.append(history_item)

    messages.append({ "role": "user", "content": message   })



    return get_completion_from_messages(messages)


gr.ChatInterface(predict).launch(debug=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Message: TVK party in tamil nadu in 2 words
# History: []
# Message: who is founder
# History: [{'role': 'user', 'metadata': None, 'content': [{'text': 'TVK party in tamil nadu in 2 words', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': 'TVK party in Tamil Nadu is known as **Tamil Viduthalai Kazhagam**.', 'type': 'text'}], 'options': None}]
# Keyboard interruption in main thread... closing server.
